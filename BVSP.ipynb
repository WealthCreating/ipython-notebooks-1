# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sys
# %pylab inline
print 'python', sys.version
print 'pandas', pd.__version__
# Out:
# Populating the interactive namespace from numpy and matplotlib
# python 2.7.6 (default, Nov 28 2013, 23:33:48)
# [GCC 4.2.1 Compatible Apple LLVM 5.0 (clang-500.2.79)]
# pandas 0.13.0

# %%
bvsp = pd.read_csv('BVSP-1993-2014.csv', parse_dates=[0])

# %%
bvsp.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
bvsp.Date.head()
# Out:
# 0   2014-02-28 00:00:00
# 1   2014-02-27 00:00:00
# 2   2014-02-26 00:00:00
# 3   2014-02-25 00:00:00
# 4   2014-02-24 00:00:00
# Name: Date, dtype: datetime64[ns]

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax.plot(bvsp.Date, bvsp.Close)
# ax.set_xticks(anual_result.index)
# ax.set_xticklabels(anual_result.index)
# ax.grid(True)
# ax.set_title('LPA')
